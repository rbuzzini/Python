# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %%
url1 = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv"
url2 = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv"

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
cars1 = pd.read_csv(url1)
cars2 = pd.read_csv(url2)

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.columns
# Out:
# Index([u'mpg', u'cylinders', u'displacement', u'horsepower', u'weight',
#        u'acceleration', u'model', u'origin', u'car', u'Unnamed: 9',
#        u'Unnamed: 10', u'Unnamed: 11', u'Unnamed: 12', u'Unnamed: 13'],
#       dtype='object')

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %%
cars2.columns
# Out:
# Index([u'mpg', u'cylinders', u'displacement', u'horsepower', u'weight',
#        u'acceleration', u'model', u'origin', u'car'],
#       dtype='object')

# %%
cars1 = cars1.loc[:,:'car']

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print("In cars1 there are {0} observations and {1} columns, while {2} rows and {3} features in cars2".format(cars1.shape[0], cars1.shape[1],
                                                                                               cars2.shape[0], cars2.shape[1]))
# Out:
# In cars1 there are 198 observations and 9 columns, while 200 rows and 9 features in cars2

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = pd.concat([cars1, cars2])
cars = cars.reset_index()

# %% [markdown]
# or

# %%
appending = cars1.append(cars2)
appending = appending.reset_index()
appending.equals(cars)
# Out:
# True

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
owners_series = pd.DataFrame(np.random.RandomState(123).randint(15000, 73000, size=cars.shape[0]), columns=['owner'])
owners_series.head()
# Out:
#    owner
# 0  67734
# 1  30725
# 2  43030
# 3  32730
# 4  69370

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owner'] = owners_series
cars.head()
# Out:
#    index   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0      0  18.0          8           307        130    3504          12.0
# 1      1  15.0          8           350        165    3693          11.5
# 2      2  18.0          8           318        150    3436          11.0
# 3      3  16.0          8           304        150    3433          12.0
# 4      4  17.0          8           302        140    3449          10.5
#
#    model  origin                        car  owner
# 0     70       1  chevrolet chevelle malibu  67734
# 1     70       1          buick skylark 320  30725
# 2     70       1         plymouth satellite  43030
# 3     70       1              amc rebel sst  32730
# 4     70       1                ford torino  69370

# %% [markdown]
# or

# %%
comparison1 = pd.concat([cars.iloc[:,:-1], owners_series], axis=1)

# %%
cars.equals(comparison1)
# Out:
# True

# %%
comparison2 = cars.iloc[:,:-1].join(owners_series)

# %%
comparison1.equals(comparison2)
# Out:
# True
